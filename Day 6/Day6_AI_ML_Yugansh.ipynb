# %%
from sklearn import datasets # import this to load the datasets
from sklearn import svm # import the classification model
from sklearn import model_selection # to load function for train test split
from sklearn import metrics # to evaluate performance of the model

# %%
data = datasets.load_iris()
X = data.data
Y = data.target
print(type(X))
print(type(Y))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
# clf_model = svm.SVC() # this is the classification model we are using
ratio=0.3
Xtrain,Xtest,ytrain,ytest= model_selection.train_test_split(X,Y,test_size=ratio,random_state=5)
svm_model=svm.SVC(kernel="linear",gamma="scale",C=4)
svm_model=svm_model.fit(Xtrain,ytrain)

ypred= svm_model.predict(Xtest)


print(Xtrain.shape,ytrain.shape)
print(Xtest.shape,ytest.shape)
# Out:
# (105, 4) (105,)
# (45, 4) (45,)

# %%
acc = metrics.accuracy_score(ypred,ytest)

conf_matrix = metrics.confusion_matrix(ypred,ytest)

report = metrics.classification_report(ypred,ytest)

print('Accuracy of the system: ', acc)
print(' Confusion matrix of the model ')
print(conf_matrix)
print("Complete report ")
print(report)
# Out:
# Accuracy of the system:  0.9777777777777777
#  Confusion matrix of the model
# [[15  0  0]
#  [ 0 15  0]
#  [ 0  1 14]]
# Complete report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       0.94      1.00      0.97        15
#            2       1.00      0.93      0.97        15
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %%
import pandas as pd
path = '/content/diabetes.csv'
data = pd.read_csv(path)
print(data.shape)
# Out:
# (768, 9)

# %% [markdown]
# for future reference this is the link for the data file
# <br>```https://nooblinus-my.sharepoint.com/:x:/g/personal/  yugansh_nooblinus_onmicrosoft_com/EWvCMvkZOrhHvt9RvYqQh0YBlHa6iMyidvIPTlUNSGZY_w?e=qjJbW5```

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X=data.drop('Outcome',axis=1,inplace=False)
y=data['Outcome']


Xtrain,Xtest,ytrain,ytest= model_selection.train_test_split(X,y,test_size=ratio,random_state=5)
print(Xtrain.shape,ytrain.shape)
print(Xtest.shape,ytest.shape)





#CReate the svm classifier
dibts_svm_model = svm.SVC(kernel='poly',gamma='scale',C=3)
dibts_svm_model = dibts_svm_model.fit(Xtrain,ytrain)
ypred = dibts_svm_model.predict(Xtest)
# Out:
# (537, 8) (537,)
# (231, 8) (231,)

# %%
acc = metrics.accuracy_score(ypred,ytest)

conf_matrix = metrics.confusion_matrix(ypred,ytest)

report = metrics.classification_report(ypred,ytest)

print('Accuracy of the system: ', acc)
print(' Confusion matrix of the model ')
print(conf_matrix)
print("Complete report ")
print(report)
# Out:
# Accuracy of the system:  0.7792207792207793
#  Confusion matrix of the model
# [[138  29]
#  [ 22  42]]
# Complete report
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84       167
#            1       0.59      0.66      0.62        64
#
#     accuracy                           0.78       231
#    macro avg       0.73      0.74      0.73       231
# weighted avg       0.79      0.78      0.78       231

# %%
# Perform the EDA on diabities
# Exploratory Data Analysis
import seaborn as sns
import matplotlib.pyplot as plt
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# Distribution plot of a look-up

plt.figure(1,figsize=(18,10))
plt.figure(figsize=(10,5))
sns.displot(data=data, x= 'Glucose', kind='hist')

# %%
# Box plot is used for checking out-liers
# Certainly! A box plot is like a visual summary of data. It shows key points like the median, quartiles, and outliers. Imagine a box with a line down the middle and
# lines attached to each side (like whiskers). The box represents the middle 50% of the data, and the whiskers show how the data spreads out
interested_cols = ['Glucose','BloodPressure','SkinThickness','Insulin','BMI']
plt.figure(1,figsize=(17,6))
sns.boxplot(data=data[interested_cols])
# Out:
# <Axes: >

# %%
plt.figure(1,figsize=(10,10))

plt.subplot(2,2,1)
sns.histplot(data['Glucose'])

plt.subplot(2,2,2)
sns.histplot(data['BloodPressure'])

plt.subplot(2,2,3)
sns.histplot(data['Insulin'])

plt.subplot(2,2,4)
sns.histplot(data['SkinThickness'])
# Out:
# <Axes: xlabel='SkinThickness', ylabel='Count'>

# %%
plt.figure(1,figsize=(10,5))
ax = sns.barplot(data=data,x='Age',hue='Outcome')
for i in(ax.containers):
  ax.bar_label(i)
plt.xticks()
# Out:
# (array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40., 45.]),
#  [Text(0.0, 0, '0'),
#   Text(5.0, 0, '5'),
#   Text(10.0, 0, '10'),
#   Text(15.0, 0, '15'),
#   Text(20.0, 0, '20'),
#   Text(25.0, 0, '25'),
#   Text(30.0, 0, '30'),
#   Text(35.0, 0, '35'),
#   Text(40.0, 0, '40'),
#   Text(45.0, 0, '45')])

# %%
age_min = data['Age'].min()
age_max = data['Age'].max()
print(age_min,age_max)
# Out:
# 21 81

# %%
#Scatter plot with corelation of age and blood pressure in which age is on X axis
plt.figure(1,figsize=(10,5))
sns.scatterplot(data=data,x='Age',y='BloodPressure')
# Out:
# <Axes: xlabel='Age', ylabel='BloodPressure'>

# %%
#  Dividing the age into various categories like Young = <=30 / Middle = 31 & <=50 / Mature = 50 and <=65 / Old Age = >65

# Young = data['Age'] <= 30
# Middle = (data['Age']>30) & (data['Age']<=50)
# Mature = (data['Age']>50) & (data['Age']<=65)
# OldAge = data['Age']>65
# agp=[Young,Middle,Mature,OldAge]

# %%
data['Age_Category'] = data['Age'].copy()

ind = data['Age'] <= 30
Young = data.loc[ind,'Age_Category'] = 'Young'

ind = (data['Age']>30) & (data['Age']<=50)
Middle = data.loc[ind,'Age_Category'] = 'Middle'

ind = (data['Age']>50) & (data['Age']<=65)
Mature = data.loc[ind,'Age_Category'] = 'Mature'

ind = data['Age']>65
OldAge = data.loc[ind,'Age_Category'] = 'OldAge'

# agp=[Young,Middle,Mature,OldAge]

data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome Age_Category
# 0                     0.627   50        1       Middle
# 1                     0.351   31        0       Middle
# 2                     0.672   32        1       Middle
# 3                     0.167   21        0        Young
# 4                     2.288   33        1       Middle

# %%
#Now, we need to add the column called age_category!
# 1. If age<=30 shows 'Young'.
# 2. If age>=31 & age<=44 shows 'Middle_Age'.
# 3. If age>=46 & age<=65 shows 'Mature_Age'.
# 4. If age>=65 shows 'old_age'.

def age_category(age):
  if(age<=30):
    return 'Young';
  elif(age>=31 and age<=44):
    return 'Middle_Age';
  elif(age>=46 and age<=65):
    return 'Mature_Age';
  else:
    return 'Old_Age';

Age=data['Age'];
data['Age_Category']=data['Age'].apply(age_category);

# %%
plt.figure(1,figsize=(13,6));
sns.countplot(data=data,x='Age_Category',hue='Outcome');
plt.show();

# %%
path = '/content/diabetes.csv'
data = pd.read_csv(path)
print(data.shape)
# Out:
# (768, 9)

# %%
import numpy as np
X=data.drop('Outcome',axis=1,inplace=False)
y=data['Outcome']

ratio=0.3
Xtrain,Xtest,ytrain,ytest= model_selection.train_test_split(X,y,test_size=ratio,random_state=5)
print(Xtrain.shape,ytrain.shape)
print(Xtest.shape,ytest.shape)

result=np.zeros((3,3))
# C_val=[1,2,3]
kern_val=["rbf","poly","linear"]

#CReate the svm classifier

for i in range(3):
  for j in kern_val:
    dibts_svm_model = svm.SVC(kernel=j,gamma='scale',C=i+1)
    dibts_svm_model = dibts_svm_model.fit(Xtrain,ytrain)
    ypred = dibts_svm_model.predict(Xtest)
    acc_val = metrics.accuracy_score(ypred,ytest)
    result[i][kern_val.index(j)]=acc_val




print('Accuracy of the system: ', acc)
print(result)
# Out:
# (537, 8) (537,)
# (231, 8) (231,)
# Accuracy of the system:  0.7965367965367965
# [[0.78354978 0.78787879 0.7965368 ]
#  [0.77489177 0.78787879 0.7965368 ]
#  [0.76623377 0.77922078 0.7965368 ]]

# %%
import pandas as pd
df = pd.DataFrame(result,index=kern_val,columns=["C=1","C=2","C=3"])

# %%
print(df)
# Out:
#              C=1       C=2       C=3
# rbf     0.783550  0.787879  0.796537
# poly    0.774892  0.787879  0.796537
# linear  0.766234  0.779221  0.796537

# %%
df=df.T
df.plot(kind='bar',figsize=(10,5))
# Out:
# <Axes: >

# %%
path= '/content/Fish.csv'
data =pd.read_csv(path)
data.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
plt.figure(1,figsize=(20,10))
plt.figure(figsize=(10,5))
sns.displot(data=data, x= 'Species', kind='hist')

# %%
plt.figure(1,figsize=(20,10))
plt.figure(figsize=(10,5))
sns.displot(data=data, x= 'Weight', kind='hist')

# %%
data['Weight'].plot(x= 'Species', kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.figure(1,figsize=(30,15))
sns.scatterplot(data=data,x='Weight',y='Species')
# Out:
# <Axes: xlabel='Weight', ylabel='Species'>

# %%
plt.figure(1,figsize=(10,10))

plt.subplot(2,2,1)
sns.histplot(data['Species'])

plt.subplot(2,2,2)
sns.histplot(data['Weight'])

plt.subplot(2,2,3)
sns.histplot(data['Height'])

plt.subplot(2,2,4)
sns.histplot(data['Width'])
# Out:
# <Axes: xlabel='Width', ylabel='Count'>

# %%
X=data.drop('Species',axis=1,inplace=False)
y=data['Species']


ratio=0.3
Xtrain,Xtest,ytrain,ytest= model_selection.train_test_split(X,y,test_size=ratio,random_state=5)
print(Xtrain.shape,ytrain.shape)
print(Xtest.shape,ytest.shape)

result=np.zeros((3,3))
# C_val=[1,2,3]
kern_val=["rbf","linear","poly"]

#Create the svm classifier

for i in range(3):
  for j in kern_val:
    fish_svm_model = svm.SVC(kernel=j,gamma='scale',C=i+1)
    fish_svm_model = fish_svm_model.fit(Xtrain,ytrain)
    ypred = fish_svm_model.predict(Xtest)
    acc_val = metrics.accuracy_score(ypred,ytest)
    result[i][kern_val.index(j)]=acc_val




print('Accuracy of the system: ', acc)
print(result)
# Out:
# (111, 6) (111,)
# (48, 6) (48,)
# Accuracy of the system:  0.7965367965367965
# [[0.47916667 0.85416667 0.3125    ]
#  [0.4375     0.875      0.3125    ]
#  [0.4375     0.85416667 0.33333333]]

# %%
df = pd.DataFrame(result,index=kern_val,columns=["C=1","C=2","C=3"])
print(df)
df=df.T
df.plot(kind='bar',figsize=(10,5))
# Out:
#              C=1       C=2       C=3
# rbf     0.479167  0.854167  0.312500
# linear  0.437500  0.875000  0.312500
# poly    0.437500  0.854167  0.333333
# <Axes: >
